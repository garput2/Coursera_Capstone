# %% [markdown]
# # The Battle of Neighborhood

# %% [markdown]
# ## Introduction

# %% [markdown]
# Burger Queen, a Canadian newly established burger joint, is aiming to discover where to build its new restaurant. The restaurant will be opened in Toronto, so as a data scientist we ought to analyze which area it may be most profitable to build the joint. The requirements set by the CEO is only places where there are not many competitors, as we have to build our brand first before trying to compete with popular and well-established joints. But, the place should be populous as well so that the burger brings profit. The CEO wants to build 3 restaurants per borough and would like to find the exact three location per borough that is needed to be bought to ensure the requirements are met.

# %% [markdown]
# ## Data

# %% [markdown]
# The neighborhood candidate data needed for this analytics are the Toronto postal code, borough, and neighborhood data which will be extracted from https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M and their longitude and latitude which will be extracted from http://cocl.us/Geospatial_data. Then, the list of nearby burger joints will be extracted with Foursquare API. After we have the rival joints data, we use the data to generate K-Means Clustering, where the cluster center or centroids determine the area where we would like to open the new three joints.

# %% [markdown]
# ### Neighborhood Candidate

# %%
#Let's import the libraries needed
import pandas as pd
from geopy.geocoders import Nominatim
import folium
import requests
from pandas.io.json import json_normalize
import numpy as np
from sklearn.cluster import KMeans
import matplotlib.cm as cm
import matplotlib.colors as colors

# %%
#Then we retrieve the postal code data from Wikipedia
url = 'https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M'
df = pd.read_html(url)
df2 = df[0]                                                                                     
df3 = df2[['Postal Code','Borough', 'Neighbourhood']]
df3
# Out:
#     Postal Code           Borough  \
# 0           M1A      Not assigned
# 1           M2A      Not assigned
# 2           M3A        North York
# 3           M4A        North York
# 4           M5A  Downtown Toronto
# ..          ...               ...
# 175         M5Z      Not assigned
# 176         M6Z      Not assigned
# 177         M7Z      Not assigned
# 178         M8Z         Etobicoke
# 179         M9Z      Not assigned
#
#                                          Neighbourhood
# 0                                         Not assigned
# 1                                         Not assigned
# 2                                            Parkwoods
# 3                                     Victoria Village
# 4                            Regent Park, Harbourfront
# ..                                                 ...
# 175                                       Not assigned
# 176                                       Not assigned
# 177                                       Not assigned
# 178  Mimico NW, The Queensway West, South of Bloor,...
# 179                                       Not assigned
#
# [180 rows x 3 columns]

# %%
#As you can see, there are lots of 'not assigned' borough and we don't need them
#Let's drop the unneeded borough
df4 = df3[df3.Borough != 'Not assigned']
df4
# Out:
#     Postal Code           Borough  \
# 2           M3A        North York
# 3           M4A        North York
# 4           M5A  Downtown Toronto
# 5           M6A        North York
# 6           M7A  Downtown Toronto
# ..          ...               ...
# 160         M8X         Etobicoke
# 165         M4Y  Downtown Toronto
# 168         M7Y      East Toronto
# 169         M8Y         Etobicoke
# 178         M8Z         Etobicoke
#
#                                          Neighbourhood
# 2                                            Parkwoods
# 3                                     Victoria Village
# 4                            Regent Park, Harbourfront
# 5                     Lawrence Manor, Lawrence Heights
# 6          Queen's Park, Ontario Provincial Government
# ..                                                 ...
# 160      The Kingsway, Montgomery Road, Old Mill North
# 165                               Church and Wellesley
# 168  Business reply mail Processing Centre, South C...
# 169  Old Mill South, King's Mill Park, Sunnylea, Hu...
# 178  Mimico NW, The Queensway West, South of Bloor,...
#
# [103 rows x 3 columns]

# %% [markdown]
# Nice! We now have the list of borough and neighborhood in Toronto. Now let's fing their latitude and longitude.

# %%
geodf=pd.read_csv('http://cocl.us/Geospatial_data')
geodf
# Out:
#     Postal Code   Latitude  Longitude
# 0           M1B  43.806686 -79.194353
# 1           M1C  43.784535 -79.160497
# 2           M1E  43.763573 -79.188711
# 3           M1G  43.770992 -79.216917
# 4           M1H  43.773136 -79.239476
# ..          ...        ...        ...
# 98          M9N  43.706876 -79.518188
# 99          M9P  43.696319 -79.532242
# 100         M9R  43.688905 -79.554724
# 101         M9V  43.739416 -79.588437
# 102         M9W  43.706748 -79.594054
#
# [103 rows x 3 columns]

# %%
#The two dataframes have the same column named 'Postal Code'
#Let's combine both dataframe and let 'Postal Code' be the combining parameter
to_merged = pd.merge(df4, geodf, on="Postal Code")
to_merged
# Out:
#     Postal Code           Borough  \
# 0           M3A        North York
# 1           M4A        North York
# 2           M5A  Downtown Toronto
# 3           M6A        North York
# 4           M7A  Downtown Toronto
# ..          ...               ...
# 98          M8X         Etobicoke
# 99          M4Y  Downtown Toronto
# 100         M7Y      East Toronto
# 101         M8Y         Etobicoke
# 102         M8Z         Etobicoke
#
#                                          Neighbourhood   Latitude  Longitude
# 0                                            Parkwoods  43.753259 -79.329656
# 1                                     Victoria Village  43.725882 -79.315572
# 2                            Regent Park, Harbourfront  43.654260 -79.360636
# 3                     Lawrence Manor, Lawrence Heights  43.718518 -79.464763
# 4          Queen's Park, Ontario Provincial Government  43.662301 -79.389494
# ..                                                 ...        ...        ...
# 98       The Kingsway, Montgomery Road, Old Mill North  43.653654 -79.506944
# 99                                Church and Wellesley  43.665860 -79.383160
# 100  Business reply mail Processing Centre, South C...  43.662744 -79.321558
# 101  Old Mill South, King's Mill Park, Sunnylea, Hu...  43.636258 -79.498509
# 102  Mimico NW, The Queensway West, South of Bloor,...  43.628841 -79.520999
#
# [103 rows x 5 columns]

# %%
#We want to know all unique borough in Toronto
to_merged['Borough'].unique()
# Out:
# array(['North York', 'Downtown Toronto', 'Etobicoke', 'Scarborough',
#        'East York', 'York', 'East Toronto', 'West Toronto',
#        'Central Toronto', 'Mississauga'], dtype=object)

# %%
#I am having trouble using Foursquare API for East Toronto and Central Toronto
#I decided to exclude East Toronto from this data

to_merge1 = to_merged[to_merged.Borough != 'East Toronto']
to_merge = to_merge1[to_merge1.Borough != 'Central Toronto']                    
to_merge
# Out:
#     Postal Code           Borough  \
# 0           M3A        North York
# 1           M4A        North York
# 2           M5A  Downtown Toronto
# 3           M6A        North York
# 4           M7A  Downtown Toronto
# ..          ...               ...
# 97          M5X  Downtown Toronto
# 98          M8X         Etobicoke
# 99          M4Y  Downtown Toronto
# 101         M8Y         Etobicoke
# 102         M8Z         Etobicoke
#
#                                          Neighbourhood   Latitude  Longitude
# 0                                            Parkwoods  43.753259 -79.329656
# 1                                     Victoria Village  43.725882 -79.315572
# 2                            Regent Park, Harbourfront  43.654260 -79.360636
# 3                     Lawrence Manor, Lawrence Heights  43.718518 -79.464763
# 4          Queen's Park, Ontario Provincial Government  43.662301 -79.389494
# ..                                                 ...        ...        ...
# 97              First Canadian Place, Underground city  43.648429 -79.382280
# 98       The Kingsway, Montgomery Road, Old Mill North  43.653654 -79.506944
# 99                                Church and Wellesley  43.665860 -79.383160
# 101  Old Mill South, King's Mill Park, Sunnylea, Hu...  43.636258 -79.498509
# 102  Mimico NW, The Queensway West, South of Bloor,...  43.628841 -79.520999
#
# [89 rows x 5 columns]

# %%
address = 'Toronto, ON'

geolocator = Nominatim(user_agent="to_explorer")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print('The geograpical coordinate of Downtown Toronto are {}, {}.'.format(latitude, longitude))
# Out:
# The geograpical coordinate of Downtown Toronto are 43.6534817, -79.3839347.

# %% [markdown]
# Looking good! Now let's move on to the next section

# %% [markdown]
# ### Foursquare API

# %%
#Let's declare our credentials first
CLIENT_ID = 'WIFWESZITOIN1EVYX3CGVYNM4ZY2QOOFPYK31ZKERQQTJBVH'
CLIENT_SECRET = 'TTED4T1YTWCNZQIGJ2A5R10OCGRHU2WFP5GV2YIEHMZCSAR2'
VERSION = '20180604'
LIMIT = 500
print('Your credentials:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)
# Out:
# Your credentials:
# CLIENT_ID: WIFWESZITOIN1EVYX3CGVYNM4ZY2QOOFPYK31ZKERQQTJBVH
# CLIENT_SECRET:TTED4T1YTWCNZQIGJ2A5R10OCGRHU2WFP5GV2YIEHMZCSAR2

# %%
boroughs = ['North York, ON', 'Downtown Toronto, ON', 'Etobicoke, ON', 'Scarborough, ON', 'East York, ON', 
            'York, ON', 'West Toronto, ON', 'Mississauga, ON']
results = {}
for borough in boroughs:
    url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&near={}&limit={}&categoryId={}'.format(
        CLIENT_ID, 
        CLIENT_SECRET, 
        VERSION, 
        borough,
        LIMIT,
        "4bf58dd8d48988d16c941735") # Burger Joints CATEGORY ID
    results[borough] = requests.get(url).json()

# %%
#See the sample
results['North York, ON']
# Out:
# {'meta': {'code': 200, 'requestId': '5f205a263ab3975ba8e324b4'},
#  'response': {'suggestedFilters': {'header': 'Tap to show:',
#    'filters': [{'name': 'Open now', 'key': 'openNow'}]},
#   'geocode': {'what': '',
#    'where': 'north york on',
#    'center': {'lat': 43.76681, 'lng': -79.4163},
#    'displayString': 'North York, ON, Canada',
#    'cc': 'CA',
#    'geometry': {'bounds': {'ne': {'lat': 43.85873, 'lng': -79.296997},
#      'sw': {'lat': 43.702629, 'lng': -79.557068}}},
#    'slug': 'north-york-ontario-canada',
#    'longId': '72057594044019040'},
#   'headerLocation': 'North York',
#   'headerFullLocation': 'North York',
#   'headerLocationGranularity': 'city',
#   'query': 'burgers',
#   'totalResults': 41,
#   'suggestedBounds': {'ne': {'lat': 43.85008397930268,
#     'lng': -79.29020232542227},
#    'sw': {'lat': 43.70496562920522, 'lng': -79.54638365797548}},
#   'groups': [{'type': 'Recommended Places',
#     'name': 'recommended',
#     'items': [{'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4d3b24e8039eb60c7462f29c',
#        'name': 'South St. Burger',
#        'location': {'address': '49 Clock Tower Road  G010',
#         'lat': 43.734274151590064,
#         'lng': -79.34365473960722,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.734274151590064,
#           'lng': -79.34365473960722}],
#         'postalCode': 'M3C 0G4',
#         'cc': 'CA',
#         'city': 'North York',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['49 Clock Tower Road  G010',
#          'North York ON M3C 0G4',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d16c941735',
#          'name': 'Burger Joint',
#          'pluralName': 'Burger Joints',
#          'shortName': 'Burgers',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/burger_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4d3b24e8039eb60c7462f29c-0'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4cc37b3fbde8f04dc69ca54b',
#        'name': 'The Burger Cellar',
#        'location': {'address': '3391 Yonge St',
#         'crossStreet': 'at Golfdale Rd',
#         'lat': 43.73236191776462,
#         'lng': -79.4038935868189,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.73236191776462,
#           'lng': -79.4038935868189}],
#         'postalCode': 'M4N 2L8',
#         'cc': 'CA',
#         'neighborhood': 'Bedford Park',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['3391 Yonge St (at Golfdale Rd)',
#          'Toronto ON M4N 2L8',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d16c941735',
#          'name': 'Burger Joint',
#          'pluralName': 'Burger Joints',
#          'shortName': 'Burgers',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/burger_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4cc37b3fbde8f04dc69ca54b-1'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b804461f964a520876230e3',
#        'name': "Johnny's Hamburgers",
#        'location': {'address': '2595 Victoria Park Ave',
#         'crossStreet': 'at Sheppard Ave E',
#         'lat': 43.774832858281265,
#         'lng': -79.32236466843996,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.774832858281265,
#           'lng': -79.32236466843996}],
#         'postalCode': 'M1T 1A4',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['2595 Victoria Park Ave (at Sheppard Ave E)',
#          'Toronto ON M1T 1A4',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d16c941735',
#          'name': 'Burger Joint',
#          'pluralName': 'Burger Joints',
#          'shortName': 'Burgers',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/burger_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b804461f964a520876230e3-2'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '514f3bc0e4b08735dad7f180',
#        'name': 'Hero Certified Burgers',
#        'location': {'address': '4698 Yonge St',
#         'lat': 43.758885006123585,
#         'lng': -79.41024925836751,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.758885006123585,
#           'lng': -79.41024925836751}],
#         'postalCode': 'M2N 5M4',
#         'cc': 'CA',
#         'city': 'North York',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['4698 Yonge St',
#          'North York ON M2N 5M4',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d16c941735',
#          'name': 'Burger Joint',
#          'pluralName': 'Burger Joints',
#          'shortName': 'Burgers',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/burger_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-514f3bc0e4b08735dad7f180-3'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4adcbb20f964a5202f2f21e3',
#        'name': 'Golden Star',
#        'location': {'address': '7123 Yonge St',
#         'crossStreet': 'at Meadowview Ave.',
#         'lat': 43.801533,
#         'lng': -79.42052,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.801533,
#           'lng': -79.42052}],
#         'postalCode': 'L3T 2A8',
#         'cc': 'CA',
#         'city': 'Thornhill',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['7123 Yonge St (at Meadowview Ave.)',
#          'Thornhill ON L3T 2A8',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d16c941735',
#          'name': 'Burger Joint',
#          'pluralName': 'Burger Joints',
#          'shortName': 'Burgers',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/burger_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4adcbb20f964a5202f2f21e3-4'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '54388a21498e1623995f065a',
#        'name': 'A&W',
#        'location': {'address': '2267 Highway #7',
#         'lat': 43.79956,
#         'lng': -79.500457,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.79956,
#           'lng': -79.500457}],
#         'postalCode': 'L4K 1V7',
#         'cc': 'CA',
#         'city': 'Concord',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['2267 Highway #7',
#          'Concord ON L4K 1V7',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d16c941735',
#          'name': 'Burger Joint',
#          'pluralName': 'Burger Joints',
#          'shortName': 'Burgers',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/burger_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-54388a21498e1623995f065a-5'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '51212da18055ce6af0c027d7',
#        'name': 'Hero Certified Burgers',
#        'location': {'address': '1800 Sheppard Avenue East  Unit 2021A',
#         'lat': 43.7772948385197,
#         'lng': -79.34458372068603,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.7772948385197,
#           'lng': -79.34458372068603}],
#         'postalCode': 'M2J 5A7',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['1800 Sheppard Avenue East  Unit 2021A',
#          'Toronto ON M2J 5A7',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d16c941735',
#          'name': 'Burger Joint',
#          'pluralName': 'Burger Joints',
#          'shortName': 'Burgers',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/burger_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '48512669'}},
#       'referralId': 'e-0-51212da18055ce6af0c027d7-6'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5c89486561f070002c452a4e',
#        'name': 'Five Guys',
#        'location': {'address': '4841 Yonge Street, Suite 118',
#         'crossStreet': 'Sheppard Avenue',
#         'lat': 43.76240027532789,
#         'lng': -79.4107626699753,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.76240027532789,
#           'lng': -79.4107626699753}],
#         'postalCode': 'M2N 5X2',
#         'cc': 'CA',
#         'neighborhood': 'Willowdale',
#         'city': 'North York',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['4841 Yonge Street, Suite 118 (Sheppard Avenue)',
#          'North York ON M2N 5X2',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d16c941735',
#          'name': 'Burger Joint',
#          'pluralName': 'Burger Joints',
#          'shortName': 'Burgers',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/burger_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5c89486561f070002c452a4e-7'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5786c16c498e4566f93f057f',
#        'name': 'Big Smoke Burger',
#        'location': {'lat': 43.752836,
#         'lng': -79.358998,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.752836,
#           'lng': -79.358998}],
#         'cc': 'CA',
#         'country': 'Canada',
#         'formattedAddress': ['Canada']},
#        'categories': [{'id': '4bf58dd8d48988d16c941735',
#          'name': 'Burger Joint',
#          'pluralName': 'Burger Joints',
#          'shortName': 'Burgers',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/burger_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5786c16c498e4566f93f057f-8'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b0ecb01f964a5201b5b23e3',
#        'name': "Harvey's",
#        'location': {'address': '3120 Dufferin St',
#         'lat': 43.71533697302975,
#         'lng': -79.45539587874885,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.71533697302975,
#           'lng': -79.45539587874885}],
#         'postalCode': 'M6A 2S6',
#         'cc': 'CA',
#         'city': 'North York',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['3120 Dufferin St',
#          'North York ON M6A 2S6',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d1c4941735',
#          'name': 'Restaurant',
#          'pluralName': 'Restaurants',
#          'shortName': 'Restaurant',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b0ecb01f964a5201b5b23e3-9'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4db86d7cfc608240bc2cbb99',
#        'name': "Uncle Betty's Diner",
#        'location': {'address': '2590 Yonge St.',
#         'crossStreet': 'at Albertus Ave.',
#         'lat': 43.7144524368588,
#         'lng': -79.40009057656115,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.7144524368588,
#           'lng': -79.40009057656115}],
#         'postalCode': 'M4P 2J3',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['2590 Yonge St. (at Albertus Ave.)',
#          'Toronto ON M4P 2J3',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d16c941735',
#          'name': 'Burger Joint',
#          'pluralName': 'Burger Joints',
#          'shortName': 'Burgers',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/burger_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4db86d7cfc608240bc2cbb99-10'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4ae083d4f964a520d47f21e3',
#        'name': "Moxie's Classic Grill",
#        'location': {'address': '1800 Sheppard Ave E',
#         'crossStreet': 'in Fairview Mall',
#         'lat': 43.777778810576905,
#         'lng': -79.34318499889385,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.777778810576905,
#           'lng': -79.34318499889385}],
#         'postalCode': 'M2J 5A7',
#         'cc': 'CA',
#         'neighborhood': 'The Peanut',
#         'city': 'North York',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['1800 Sheppard Ave E (in Fairview Mall)',
#          'North York ON M2J 5A7',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d14e941735',
#          'name': 'American Restaurant',
#          'pluralName': 'American Restaurants',
#          'shortName': 'American',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4ae083d4f964a520d47f21e3-11'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '58a8dcaa6119f47b9a94dc05',
#        'name': 'A&W',
#        'location': {'address': '1277 York Mills Road',
#         'lat': 43.760643076161315,
#         'lng': -79.3268649067081,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.760643076161315,
#           'lng': -79.3268649067081}],
#         'postalCode': 'M3A 1Z5',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['1277 York Mills Road',
#          'Toronto ON M3A 1Z5',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d16c941735',
#          'name': 'Burger Joint',
#          'pluralName': 'Burger Joints',
#          'shortName': 'Burgers',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/burger_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-58a8dcaa6119f47b9a94dc05-12'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b5271a2f964a520967d27e3',
#        'name': 'Burger King',
#        'location': {'address': '1077 Wilson Ave',
#         'lat': 43.72672161070407,
#         'lng': -79.48105484247213,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.72672161070407,
#           'lng': -79.48105484247213}],
#         'postalCode': 'M3K 1G7',
#         'cc': 'CA',
#         'city': 'North York',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['1077 Wilson Ave',
#          'North York ON M3K 1G7',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d16e941735',
#          'name': 'Fast Food Restaurant',
#          'pluralName': 'Fast Food Restaurants',
#          'shortName': 'Fast Food',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/fastfood_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b5271a2f964a520967d27e3-13'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4fc7a0dfe4b0a6960d193b28',
#        'name': 'Five Guys',
#        'location': {'address': '865 York Mills Rd',
#         'lat': 43.75451390200428,
#         'lng': -79.35000397292158,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.75451390200428,
#           'lng': -79.35000397292158}],
#         'postalCode': 'M3B 1Y6',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['865 York Mills Rd',
#          'Toronto ON M3B 1Y6',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d16c941735',
#          'name': 'Burger Joint',
#          'pluralName': 'Burger Joints',
#          'shortName': 'Burgers',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/burger_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4fc7a0dfe4b0a6960d193b28-14'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4c796e0581bca0939d66fd14',
#        'name': "Wimpy's Diner",
#        'location': {'address': '199 Sheppard Ave. E',
#         'crossStreet': 'at Willowdale Ave.',
#         'lat': 43.76397143768718,
#         'lng': -79.39886788029243,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.76397143768718,
#           'lng': -79.39886788029243}],
#         'cc': 'CA',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['199 Sheppard Ave. E (at Willowdale Ave.)',
#          'Toronto ON',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d16c941735',
#          'name': 'Burger Joint',
#          'pluralName': 'Burger Joints',
#          'shortName': 'Burgers',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/burger_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4c796e0581bca0939d66fd14-15'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b26f64ff964a520868324e3',
#        'name': 'A&W',
#        'location': {'address': '1585 Warden Avenue',
#         'crossStreet': '401',
#         'lat': 43.76627195201865,
#         'lng': -79.30184693144743,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.76627195201865,
#           'lng': -79.30184693144743}],
#         'postalCode': 'M1R 2S9',
#         'cc': 'CA',
#         'neighborhood': 'Wexford',
#         'city': 'Scarborough',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['1585 Warden Avenue (401)',
#          'Scarborough ON M1R 2S9',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d16c941735',
#          'name': 'Burger Joint',
#          'pluralName': 'Burger Joints',
#          'shortName': 'Burgers',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/burger_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b26f64ff964a520868324e3-16'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4d12ac7012916dcba815d88a',
#        'name': 'Hero Certified Burgers',
#        'location': {'address': '305 York Mills Road',
#         'crossStreet': 'Bayview Ave',
#         'lat': 43.74740980372292,
#         'lng': -79.38463420961683,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.74740980372292,
#           'lng': -79.38463420961683}],
#         'cc': 'CA',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['305 York Mills Road (Bayview Ave)',
#          'Toronto ON',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d16c941735',
#          'name': 'Burger Joint',
#          'pluralName': 'Burger Joints',
#          'shortName': 'Burgers',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/burger_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4d12ac7012916dcba815d88a-17'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4edeeba1be7b760697d35b5e',
#        'name': 'Bier Markt',
#        'location': {'address': "67 O'neil Rd",
#         'crossStreet': 'at Shops at Don Mills',
#         'lat': 43.73367930227106,
#         'lng': -79.34446421133993,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.73367930227106,
#           'lng': -79.34446421133993}],
#         'postalCode': 'M3C 0H2',
#         'cc': 'CA',
#         'city': 'North York',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ["67 O'neil Rd (at Shops at Don Mills)",
#          'North York ON M3C 0H2',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d1c4941735',
#          'name': 'Restaurant',
#          'pluralName': 'Restaurants',
#          'shortName': 'Restaurant',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4edeeba1be7b760697d35b5e-18'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4c06b4ac9e1ab713c3de5243',
#        'name': 'South St. Burger',
#        'location': {'address': '2215 Steeles Avenue West',
#         'lat': 43.785181631941676,
#         'lng': -79.47788787332698,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.785181631941676,
#           'lng': -79.47788787332698}],
#         'postalCode': 'M3J 3N2',
#         'cc': 'CA',
#         'city': 'North York',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['2215 Steeles Avenue West',
#          'North York ON M3J 3N2',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d16c941735',
#          'name': 'Burger Joint',
#          'pluralName': 'Burger Joints',
#          'shortName': 'Burgers',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/burger_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4c06b4ac9e1ab713c3de5243-19'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4fca5aeee4b053b8ae5eba6d',
#        'name': 'Big Smoke Burger',
#        'location': {'address': '3401 Dufferin St,Yorkdale Shopping Centre',
#         'crossStreet': 'in Yorkdale Shopping Centre',
#         'lat': 43.724684,
#         'lng': -79.454172,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.724684,
#           'lng': -79.454172}],
#         'postalCode': 'M6A 2T9',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['3401 Dufferin St,Yorkdale Shopping Centre (in Yorkdale Shopping Centre)',
#          'Toronto ON M6A 2T9',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d16c941735',
#          'name': 'Burger Joint',
#          'pluralName': 'Burger Joints',
#          'shortName': 'Burgers',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/burger_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4fca5aeee4b053b8ae5eba6d-20'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4ec81ea00aaf9c3ccd213385',
#        'name': 'South St. Burger',
#        'location': {'address': '2901 Bayview Ave',
#         'lat': 43.76873662189499,
#         'lng': -79.38641297637251,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.76873662189499,
#           'lng': -79.38641297637251}],
#         'postalCode': 'M2K 1E6',
#         'cc': 'CA',
#         'city': 'North York',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['2901 Bayview Ave',
#          'North York ON M2K 1E6',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d16c941735',
#          'name': 'Burger Joint',
#          'pluralName': 'Burger Joints',
#          'shortName': 'Burgers',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/burger_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4ec81ea00aaf9c3ccd213385-21'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b32769df964a5205a0c25e3',
#        'name': "Harvey's",
#        'location': {'address': '3343 Bayview Ave',
#         'lat': 43.7922865144151,
#         'lng': -79.39302398965629,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.7922865144151,
#           'lng': -79.39302398965629}],
#         'postalCode': 'M2K 1G4',
#         'cc': 'CA',
#         'city': 'North York',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['3343 Bayview Ave',
#          'North York ON M2K 1G4',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d1c4941735',
#          'name': 'Restaurant',
#          'pluralName': 'Restaurants',
#          'shortName': 'Restaurant',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b32769df964a5205a0c25e3-22'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '501c04a7e4b03059fc21ed0f',
#        'name': 'Hero Certified Burgers',
#        'location': {'address': '4700 Keele St.',
#         'crossStreet': 'In York Lanes Shopping Centre',
#         'lat': 43.77422189874931,
#         'lng': -79.50180630127186,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.77422189874931,
#           'lng': -79.50180630127186}],
#         'postalCode': 'M3J 1P3',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['4700 Keele St. (In York Lanes Shopping Centre)',
#          'Toronto ON M3J 1P3',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d16c941735',
#          'name': 'Burger Joint',
#          'pluralName': 'Burger Joints',
#          'shortName': 'Burgers',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/burger_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-501c04a7e4b03059fc21ed0f-23'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b832e14f964a5200dfc30e3',
#        'name': 'Wendy’s',
#        'location': {'address': '5095 Yonge Street',
#         'crossStreet': 'btwn Empress Ave & Hillcrest Ave',
#         'lat': 43.76846127243853,
#         'lng': -79.4123771060805,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.76846127243853,
#           'lng': -79.4123771060805}],
#         'postalCode': 'M2N 6Z4',
#         'cc': 'CA',
#         'city': 'North York',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['5095 Yonge Street (btwn Empress Ave & Hillcrest Ave)',
#          'North York ON M2N 6Z4',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d16c941735',
#          'name': 'Burger Joint',
#          'pluralName': 'Burger Joints',
#          'shortName': 'Burgers',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/burger_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b832e14f964a5200dfc30e3-24'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4c02b933310fc9b64fe1c461',
#        'name': 'JOEY Don mills',
#        'location': {'address': "75 O'Neill Rd",
#         'lat': 43.733990328997315,
#         'lng': -79.34473422057377,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.733990328997315,
#           'lng': -79.34473422057377}],
#         'postalCode': 'M3C 0H2',
#         'cc': 'CA',
#         'city': 'North York',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ["75 O'Neill Rd",
#          'North York ON M3C 0H2',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d157941735',
#          'name': 'New American Restaurant',
#          'pluralName': 'New American Restaurants',
#          'shortName': 'New American',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/newamerican_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4c02b933310fc9b64fe1c461-25'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b008142f964a520fc3e22e3',
#        'name': 'Wendy’s',
#        'location': {'address': '1002 Lawrence Ave. W.',
#         'lat': 43.71299143087544,
#         'lng': -79.46135383914225,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.71299143087544,
#           'lng': -79.46135383914225}],
#         'postalCode': 'M6A 1C3',
#         'cc': 'CA',
#         'city': 'North York',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['1002 Lawrence Ave. W.',
#          'North York ON M6A 1C3',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d16c941735',
#          'name': 'Burger Joint',
#          'pluralName': 'Burger Joints',
#          'shortName': 'Burgers',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/burger_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b008142f964a520fc3e22e3-26'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4bbe3b165ce0d13adbd3df57',
#        'name': 'Wendy’s',
#        'location': {'address': '4700 Keele Street',
#         'crossStreet': 'in the Student Centre',
#         'lat': 43.77391,
#         'lng': -79.502963,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.77391,
#           'lng': -79.502963}],
#         'postalCode': 'M3J 1P3',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['4700 Keele Street (in the Student Centre)',
#          'Toronto ON M3J 1P3',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d16c941735',
#          'name': 'Burger Joint',
#          'pluralName': 'Burger Joints',
#          'shortName': 'Burgers',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/burger_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4bbe3b165ce0d13adbd3df57-27'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5c5e2c91cabcff002c8740e8',
#        'name': "The Burger's Priest",
#        'location': {'address': '860 York Mills Road Unit 2',
#         'lat': 43.755012724252325,
#         'lng': -79.3517972627634,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.755012724252325,
#           'lng': -79.3517972627634}],
#         'postalCode': 'M3B 1Y4',
#         'cc': 'CA',
#         'city': 'North York',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['860 York Mills Road Unit 2',
#          'North York ON M3B 1Y4',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d16c941735',
#          'name': 'Burger Joint',
#          'pluralName': 'Burger Joints',
#          'shortName': 'Burgers',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/burger_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5c5e2c91cabcff002c8740e8-28'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5ac6a1199411f261760fde9f',
#        'name': 'South St. Burger',
#        'location': {'address': '1542 Avenue Road',
#         'crossStreet': 'Lawrence',
#         'lat': 43.7230841,
#         'lng': -79.4161395,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.7230841,
#           'lng': -79.4161395}],
#         'postalCode': 'M5M 3X5',
#         'cc': 'CA',
#         'city': 'North York',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['1542 Avenue Road (Lawrence)',
#          'North York ON M5M 3X5',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d16c941735',
#          'name': 'Burger Joint',
#          'pluralName': 'Burger Joints',
#          'shortName': 'Burgers',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/burger_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5ac6a1199411f261760fde9f-29'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '57658311498ede5f06c0bca5',
#        'name': 'McCoy Burger Company',
#        'location': {'address': '3334 Yonge Street',
#         'lat': 43.731457,
#         'lng': -79.40403,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.731457,
#           'lng': -79.40403}],
#         'cc': 'CA',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['3334 Yonge Street', 'Toronto ON', 'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d16c941735',
#          'name': 'Burger Joint',
#          'pluralName': 'Burger Joints',
#          'shortName': 'Burgers',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/burger_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-57658311498ede5f06c0bca5-30'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5b5cb451fe63bd002b5acbd7',
#        'name': 'Burgers Park',
#        'location': {'address': '10 William Sylvester Drive',
#         'lat': 43.774608,
#         'lng': -79.336281,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.774608,
#           'lng': -79.336281}],
#         'postalCode': 'M2J 0A7',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['10 William Sylvester Drive',
#          'Toronto ON M2J 0A7',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d16c941735',
#          'name': 'Burger Joint',
#          'pluralName': 'Burger Joints',
#          'shortName': 'Burgers',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/burger_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5b5cb451fe63bd002b5acbd7-31'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '50c90cd1e4b017310c8944f9',
#        'name': 'Hero Certified Burgers',
#        'location': {'address': '8750 Bayview Ave.',
#         'crossStreet': 'Bayview Ave. and High Tech Rd.',
#         'lat': 43.84348769066189,
#         'lng': -79.40823876351274,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.84348769066189,
#           'lng': -79.40823876351274}],
#         'postalCode': 'L4B 4V9',
#         'cc': 'CA',
#         'city': 'Richmond Hill',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['8750 Bayview Ave. (Bayview Ave. and High Tech Rd.)',
#          'Richmond Hill ON L4B 4V9',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d16c941735',
#          'name': 'Burger Joint',
#          'pluralName': 'Burger Joints',
#          'shortName': 'Burgers',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/burger_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-50c90cd1e4b017310c8944f9-32'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b5b923bf964a520ef0729e3',
#        'name': 'Burger Hut',
#        'location': {'address': '804 Sheppard Ave E',
#         'lat': 43.7705458866236,
#         'lng': -79.3731098901543,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.7705458866236,
#           'lng': -79.3731098901543}],
#         'cc': 'CA',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['804 Sheppard Ave E', 'Toronto ON', 'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d16c941735',
#          'name': 'Burger Joint',
#          'pluralName': 'Burger Joints',
#          'shortName': 'Burgers',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/burger_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b5b923bf964a520ef0729e3-33'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4e766c697d8b91760381a5b3',
#        'name': "Burgy's Goldburger",
#        'location': {'address': '7000 Bathurst St',
#         'crossStreet': 'Steeles ave',
#         'lat': 43.793108856992376,
#         'lng': -79.44642134527288,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.793108856992376,
#           'lng': -79.44642134527288}],
#         'postalCode': 'L4J 7L1',
#         'cc': 'CA',
#         'city': 'Thornhill',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['7000 Bathurst St (Steeles ave)',
#          'Thornhill ON L4J 7L1',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d16c941735',
#          'name': 'Burger Joint',
#          'pluralName': 'Burger Joints',
#          'shortName': 'Burgers',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/burger_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4e766c697d8b91760381a5b3-34'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b4fbfc5f964a520e61327e3',
#        'name': "Montana's",
#        'location': {'address': '2011 Steeles Ave W',
#         'crossStreet': 'at  Dufferin St.',
#         'lat': 43.786644823820026,
#         'lng': -79.47149350780924,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.786644823820026,
#           'lng': -79.47149350780924}],
#         'postalCode': 'M3J 3N3',
#         'cc': 'CA',
#         'city': 'North York',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['2011 Steeles Ave W (at  Dufferin St.)',
#          'North York ON M3J 3N3',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d1c4941735',
#          'name': 'Restaurant',
#          'pluralName': 'Restaurants',
#          'shortName': 'Restaurant',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b4fbfc5f964a520e61327e3-35'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b477a4ff964a520623326e3',
#        'name': "McDonald's",
#        'location': {'address': '747 Don Mills Road',
#         'lat': 43.714692448066195,
#         'lng': -79.33381727976229,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.714692448066195,
#           'lng': -79.33381727976229}],
#         'postalCode': 'M3C 1T2',
#         'cc': 'CA',
#         'city': 'North York',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['747 Don Mills Road',
#          'North York ON M3C 1T2',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d16e941735',
#          'name': 'Fast Food Restaurant',
#          'pluralName': 'Fast Food Restaurants',
#          'shortName': 'Fast Food',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/fastfood_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'flags': {'outsideRadius': True},
#       'referralId': 'e-0-4b477a4ff964a520623326e3-36'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4af0ba6ef964a5209bde21e3',
#        'name': "McDonald's",
#        'location': {'address': '808 York Mills Rd., Building D, Unit 1',
#         'crossStreet': 'at Leslie St',
#         'lat': 43.753641625996,
#         'lng': -79.35895392638469,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.753641625996,
#           'lng': -79.35895392638469}],
#         'postalCode': 'M3B 1X8',
#         'cc': 'CA',
#         'city': 'North York',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['808 York Mills Rd., Building D, Unit 1 (at Leslie St)',
#          'North York ON M3B 1X8',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d16e941735',
#          'name': 'Fast Food Restaurant',
#          'pluralName': 'Fast Food Restaurants',
#          'shortName': 'Fast Food',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/fastfood_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4af0ba6ef964a5209bde21e3-37'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b046a62f964a520035422e3',
#        'name': "Harvey's",
#        'location': {'address': '898 Don Mills Rd',
#         'lat': 43.726602588537574,
#         'lng': -79.34103479447748,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.726602588537574,
#           'lng': -79.34103479447748}],
#         'postalCode': 'M3C 1V6',
#         'cc': 'CA',
#         'city': 'North York',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['898 Don Mills Rd',
#          'North York ON M3C 1V6',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d1c4941735',
#          'name': 'Restaurant',
#          'pluralName': 'Restaurants',
#          'shortName': 'Restaurant',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b046a62f964a520035422e3-38'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5d03e75d1f8ed6002ccfd8b1',
#        'name': "Jack Astor's Bar & Grill",
#        'location': {'address': '5051 Yonge Street, Unit #2',
#         'lat': 43.76702262258356,
#         'lng': -79.41225305825523,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.76702262258356,
#           'lng': -79.41225305825523}],
#         'postalCode': 'M2N 5P2',
#         'cc': 'CA',
#         'city': 'North York',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['5051 Yonge Street, Unit #2',
#          'North York ON M2N 5P2',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d155941735',
#          'name': 'Gastropub',
#          'pluralName': 'Gastropubs',
#          'shortName': 'Gastropub',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/gastropub_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5d03e75d1f8ed6002ccfd8b1-39'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b1cb47af964a520270924e3',
#        'name': "McDonald's",
#        'location': {'address': '2625F Weston Road',
#         'crossStreet': 'on 401 Hwy',
#         'lat': 43.71156191784601,
#         'lng': -79.53473905195034,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.71156191784601,
#           'lng': -79.53473905195034}],
#         'postalCode': 'M9N 3X2',
#         'cc': 'CA',
#         'city': 'North York',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['2625F Weston Road (on 401 Hwy)',
#          'North York ON M9N 3X2',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d16e941735',
#          'name': 'Fast Food Restaurant',
#          'pluralName': 'Fast Food Restaurants',
#          'shortName': 'Fast Food',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/fastfood_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'flags': {'outsideRadius': True},
#       'referralId': 'e-0-4b1cb47af964a520270924e3-40'}]}]}}

# %%
to_venues={}
for borough in boroughs:
    venues = json_normalize(results[borough]['response']['groups'][0]['items'])
    to_venues[borough] = venues[['venue.name', 'venue.location.address', 'venue.location.lat', 'venue.location.lng']]
    to_venues[borough].columns = ['Name', 'Address', 'Latitude', 'Longitude']

# %%
#See sample
to_venues['Mississauga, ON'].head()
# Out:
#                   Name                Address   Latitude  Longitude
# 0           On the bun    14-5030 Maingate Dr  43.629843 -79.627587
# 1            Five Guys  6045 Mavis Rd, Unit 3  43.613328 -79.695366
# 2  The Burger's Priest     129 Lakeshore Rd E  43.554373 -79.582291
# 3         Union Burger    4188 Living Arts Dr  43.589846 -79.647793
# 4                  A&W       2930 Argentia Rd  43.598628 -79.781539

# %%
combined = to_venues['North York, ON'].append(to_venues['Downtown Toronto, ON'], ignore_index=True)
combined1 = combined.append(to_venues['Etobicoke, ON'], ignore_index=True)
combined2 = combined1.append(to_venues['Scarborough, ON'], ignore_index=True)
combined3 = combined2.append(to_venues['East York, ON'], ignore_index=True)
combined4 = combined3.append(to_venues['York, ON'], ignore_index=True)
combined5 = combined4.append(to_venues['West Toronto, ON'], ignore_index=True)
combined6 = combined5.append(to_venues['Mississauga, ON'], ignore_index=True)
combined6
# Out:
#                           Name                                      Address  \
# 0             South St. Burger                    49 Clock Tower Road  G010
# 1            The Burger Cellar                                3391 Yonge St
# 2          Johnny's Hamburgers                       2595 Victoria Park Ave
# 3       Hero Certified Burgers                                4698 Yonge St
# 4                  Golden Star                                7123 Yonge St
# ..                         ...                                          ...
# 478  Fionn MacCool's Britannia                      825 Britannia Road West
# 479         The Yorkshire Arms                          1201 Britannia Rd W
# 480              Master Steaks                               5895 Dixie Rd.
# 481            Fionn MacCool's  Toronto Pearson International Airport (YYZ)
# 482                   Harvey's                             6995 Laddie Cres
#
#       Latitude  Longitude
# 0    43.734274 -79.343655
# 1    43.732362 -79.403894
# 2    43.774833 -79.322365
# 3    43.758885 -79.410249
# 4    43.801533 -79.420520
# ..         ...        ...
# 478  43.609581 -79.699215
# 479  43.602963 -79.706652
# 480  43.653483 -79.644318
# 481  43.685422 -79.621352
# 482  43.716012 -79.626508
#
# [483 rows x 4 columns]

# %%
map_burger = folium.Map(location=[latitude, longitude], zoom_start=9)

for lat, lng, label in zip(combined6['Latitude'], combined6['Longitude'], combined6['Name']):
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_burger)  
    
map_burger
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# As you can see, above is the map containing all the burger joints in Toronto. This map is only for reference. In the end, what matters are the maps of each borough and the restaurants inside them.

# %% [markdown]
# ## Methodology

# %% [markdown]
# In order to find those three locations, I will be using K-means clustering with k = 3. I decided to use that because areas containing burger joints means that it is strategically area with high demography, so we are not afraid of potentially building our joint in area without population. However, it still stands that we have to be not too close to other joints. With k-means clustering, we will create k-number of centroids which is supposed to be the point where all nearby joints has similar distance to the point. Therefore, we can assume that it is not too close to the other joints.

# %% [markdown]
# ## Analysis

# %% [markdown]
# First, let's define all needed functions.

# %%
def findlatlang(borough):
    add1 = borough
    geolocator = Nominatim(user_agent=borough+"explorer")
    loc1 = geolocator.geocode(add1)
    lat1 = loc1.latitude
    long1 = loc1.longitude
    return lat1, long1

# %%
def findarea(borough):
    a = to_venues[borough].drop(['Name', 'Address'], 1)
    kclusters = 3
    kmeans = KMeans(n_clusters=kclusters, n_init=10).fit(a)
    centroid = kmeans.cluster_centers_
    Locs = ['Area 1', 'Area 2', 'Area 3']
    CentroFrame = pd.DataFrame(centroid)
    CentroFrame.columns = ['Latitude', 'Longitude']
    CentroFrame['Location'] = Locs
    return CentroFrame

# %% [markdown]
# Then, we use the function with each borough to find the location and create a map.

# %% [markdown]
# ### North York

# %%
loc_noyo = findlatlang('North York, ON')
print(loc_noyo)
cf_noyo = findarea('North York, ON')
print(cf_noyo)
# Out:
# (43.7543263, -79.44911696639593)
#     Latitude  Longitude Location
# 0  43.751081 -79.484132   Area 1
# 1  43.752712 -79.340172   Area 2
# 2  43.764950 -79.405064   Area 3

# %%
map_noyo = folium.Map(location=[loc_noyo[0], loc_noyo[1]], zoom_start=12)

for lat, lon, label in zip(cf_noyo['Latitude'], cf_noyo['Longitude'], cf_noyo['Location']):
    folium.CircleMarker(
        [lat, lon],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7).add_to(map_noyo)
       
map_noyo
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ### Downtown Toronto

# %%
loc_doto = findlatlang('Downtown Toronto, ON')
print(loc_doto)
cf_doto = findarea('Downtown Toronto, ON')
print(cf_doto)
# Out:
# (43.6563221, -79.3809161)
#     Latitude  Longitude Location
# 0  43.648052 -79.387662   Area 1
# 1  43.653827 -79.381233   Area 2
# 2  43.649311 -79.379159   Area 3

# %%
map_doto = folium.Map(location=[loc_doto[0], loc_doto[1]], zoom_start=15)

for lat, lon, label in zip(cf_doto['Latitude'], cf_doto['Longitude'], cf_doto['Location']):
    folium.CircleMarker(
        [lat, lon],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7).add_to(map_doto)
       
map_doto
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ### Etobicoke

# %%
loc_eto = findlatlang('Etobicoke, ON')
print(loc_eto)
cf_eto = findarea('Etobicoke, ON')
print(cf_eto)
# Out:
# (43.6435559, -79.5656326)
#     Latitude  Longitude Location
# 0  43.684930 -79.610814   Area 1
# 1  43.616143 -79.556612   Area 2
# 2  43.637102 -79.505608   Area 3

# %%
map_eto = folium.Map(location=[loc_eto[0], loc_eto[1]], zoom_start=12)

for lat, lon, label in zip(cf_eto['Latitude'], cf_eto['Longitude'], cf_eto['Location']):
    folium.CircleMarker(
        [lat, lon],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7).add_to(map_eto)
       
map_eto
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ### Scarborough

# %%
loc_sc = findlatlang('Scarborough, ON')
print(loc_sc)
cf_sc = findarea('Scarborough, ON')
print(cf_sc)
# Out:
# (43.773077, -79.257774)
#     Latitude  Longitude Location
# 0  43.790821 -79.296103   Area 1
# 1  43.726828 -79.280640   Area 2
# 2  43.789862 -79.183114   Area 3

# %%
map_sc = folium.Map(location=[loc_sc[0], loc_sc[1]], zoom_start=12)

for lat, lon, label in zip(cf_sc['Latitude'], cf_sc['Longitude'], cf_sc['Location']):
    folium.CircleMarker(
        [lat, lon],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7).add_to(map_sc)
       
map_sc
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ### East York

# %%
loc_ey = findlatlang('East York, ON')
print(loc_ey)
cf_ey = findarea('East York, ON')
print(cf_ey)
# Out:
# (43.699971000000005, -79.33251996261595)
#     Latitude  Longitude Location
# 0  43.679343 -79.346659   Area 1
# 1  43.679750 -79.313439   Area 2
# 2  43.707899 -79.344037   Area 3

# %%
map_ey = folium.Map(location=[loc_ey[0], loc_ey[1]], zoom_start=13)

for lat, lon, label in zip(cf_ey['Latitude'], cf_ey['Longitude'], cf_ey['Location']):
    folium.CircleMarker(
        [lat, lon],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7).add_to(map_ey)
       
map_ey
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ### York

# %%
loc_yo = findlatlang('York, ON')
print(loc_yo)
cf_yo = findarea('York, ON')
print(cf_yo)
# Out:
# (43.6896191, -79.479188)
#     Latitude  Longitude Location
# 0  43.684366 -79.437440   Area 1
# 1  44.353646 -79.649221   Area 2
# 2  43.886043 -79.304222   Area 3

# %%
map_yo = folium.Map(location=[loc_yo[0], loc_yo[1]], zoom_start=8)

for lat, lon, label in zip(cf_yo['Latitude'], cf_yo['Longitude'], cf_yo['Location']):
    folium.CircleMarker(
        [lat, lon],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7).add_to(map_yo)
       
map_yo
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ### West Toronto

# %%
loc_wt = findlatlang('West Toronto, ON')
print(loc_wt)
cf_wt = findarea('West Toronto, ON')
print(cf_wt)
# Out:
# (43.6534817, -79.3839347)
#     Latitude  Longitude Location
# 0  43.652689 -79.495731   Area 1
# 1  43.655253 -79.408509   Area 2
# 2  43.664295 -79.450047   Area 3

# %%
map_wt = folium.Map(location=[loc_wt[0], loc_wt[1]], zoom_start=12)

for lat, lon, label in zip(cf_wt['Latitude'], cf_wt['Longitude'], cf_wt['Location']):
    folium.CircleMarker(
        [lat, lon],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7).add_to(map_wt)
       
map_wt
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ### Mississauga

# %%
loc_mi = findlatlang('Mississauga, ON')
print(loc_mi)
cf_mi = findarea('Mississauga, ON')
print(cf_mi)
# Out:
# (43.590338, -79.645729)
#     Latitude  Longitude Location
# 0  43.591486 -79.630629   Area 1
# 1  43.576159 -79.720029   Area 2
# 2  43.673471 -79.625325   Area 3

# %%
map_mi = folium.Map(location=[loc_mi[0], loc_mi[1]], zoom_start=11)

for lat, lon, label in zip(cf_mi['Latitude'], cf_mi['Longitude'], cf_mi['Location']):
    folium.CircleMarker(
        [lat, lon],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7).add_to(map_mi)
       
map_mi
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## Results

# %% [markdown]
# Using the data from Wikipedia, we obtained data regarding to all borough and neighborhood in Toronto. Then we are able to obtain the name of unique boroughs that is used in further analysis.
#
# Using the data from Foursquare, we obtained data regarding location of rival burger joints on each borough. It is needed to find the location which requirements meet the requests of the CEO.
#
# After that, we used K-Means clustering to cluster the location of rival burger joints in order to find the centroids. The centroids are the location which is predicted to meet the requirements from the CEO
#
# After the centroids of each borough is found, we use Geopy and Folium to generate a map to visualize the data.

# %% [markdown]
# ## Conclusion

# %% [markdown]
# Now we have 3 locations from each borough where we should consider building our first 3 joints in the borough. As we have the latitude and longitude of each area, it is a simple task to translate it to street number using other user-friendly apps such as Google Maps to find the location in real life.
#
# As we are using n_init = 10, it is considered the best option from 10 tries so we may say that it is almost the ideal location by considering distance to other joints and number of population around the area.
#
# Final decission on optimal joint location will be made by stakeholders based on specific characteristics of neighborhoods and locations in every recommended zone, taking into consideration additional factors like attractiveness of each location (proximity to park or water), levels of noise / proximity to major roads, real estate availability, prices, social and economic dynamics of every neighborhood etc.
